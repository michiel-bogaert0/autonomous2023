# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %%
# read npy file
X_sol_intermediate = np.load('X_sol_intermediate.npy')

# %%
# read npz file
data = np.load('solution_converged.npz')
X_sol_intermediate = data['X_sol_intermediate']
U_sol = data['U_sol_intermediate']
inf_pr = data['info_pr']
inf_du = data['info_du']

# %%
fig, ax = plt.subplots()

ax.plot(np.arange(len(inf_pr)), inf_pr, label="inf_pr")
ax.plot(np.arange(len(inf_du)), inf_du, label="inf_du")

ax.legend(loc="upper right")
ax.set_yscale("log")

# %%
num_plots = len(X_sol_intermediate)
print(num_plots)

colors = cm.viridis(np.linspace(0, 1, num_plots))

for i, x in enumerate(X_sol_intermediate):
    plt.plot(x[0], x[1], color=colors[i], label=f'Plot {i+1}')
# plt.legend()
# Out:
# 230

# %%
# read npz file
data = np.load('solution_non_converged.npz')
X_sol_intermediate = data['X_sol_intermediate']
U_sol = data['U_sol_intermediate']
inf_pr = data['info_pr']
inf_du = data['info_du']

# %%
fig, ax = plt.subplots()

ax.plot(np.arange(len(inf_pr)), inf_pr, label="inf_pr")
ax.plot(np.arange(len(inf_du)), inf_du, label="inf_du")

ax.legend(loc="upper right")
ax.set_yscale("log")

# %%
num_plots = len(X_sol_intermediate)
print(num_plots)

colors = cm.viridis(np.linspace(0, 1, num_plots))

for i, x in enumerate(X_sol_intermediate):
    plt.plot(x[0], x[1], color=colors[i], label=f'Plot {i+1}')
# plt.legend()
# Out:
# 305

# %%
data = np.load('solution_no_constraints.npz')
X_sol_intermediate = data['X_sol_intermediate']
U_sol = data['U_sol_intermediate']
inf_pr = data['info_pr']
inf_du = data['info_du']

# %%
fig, ax = plt.subplots()

ax.plot(np.arange(len(inf_pr)), inf_pr, label="inf_pr")
ax.plot(np.arange(len(inf_du)), inf_du, label="inf_du")

ax.legend(loc="upper right")
ax.set_yscale("log")

# %%
num_plots = len(X_sol_intermediate)
print(num_plots)

colors = cm.viridis(np.linspace(0, 1, num_plots))

for i, x in enumerate(X_sol_intermediate):
    plt.plot(x[0], x[1], color=colors[i], label=f'Plot {i+1}')
# plt.legend()
# Out:
# 331

# %%
data = np.load('solution.npz')
X_sol_intermediate = data['X_sol_intermediate']
U_sol = data['U_sol_intermediate']
inf_pr = data['info_pr']
inf_du = data['info_du']

fig, ax = plt.subplots()

ax.plot(np.arange(len(inf_pr)), inf_pr, label="inf_pr")
ax.plot(np.arange(len(inf_du)), inf_du, label="inf_du")

ax.legend(loc="upper right")
ax.set_yscale("log")

plt.show()

num_plots = len(X_sol_intermediate)
print(num_plots)

colors = cm.viridis(np.linspace(0, 1, num_plots))

for i, x in enumerate(X_sol_intermediate):
    plt.plot(x[0], x[1], color=colors[i], label=f'Plot {i+1}')
# plt.legend()
# Out:
# 519

# %%
# read npz file
data = np.load('solution.npz')
X_sol_intermediate = data['X_sol_intermediate']
U_sol = data['U_sol_intermediate']
inf_pr = data['info_pr']
inf_du = data['info_du']
obj = data['info_obj']
# exec_times = data['exec_times']

fig, ax = plt.subplots()

ax.plot(np.arange(len(inf_pr)), inf_pr, label="inf_pr")
ax.plot(np.arange(len(inf_du)), inf_du, label="inf_du")

ax.legend(loc="upper right")
ax.set_yscale("log")
plt.show()

num_plots = len(X_sol_intermediate)
print(num_plots)

colors = cm.viridis(np.linspace(0, 1, num_plots))
# temp_colors = cm.viridis(np.linspace(0, 1, 10))
for i, x in enumerate(X_sol_intermediate[:]):
    plt.plot(x[0], x[1], color=colors[i], label=f'Plot {i+1}')
    
# plt.legend()
plt.show()

plt.show()
# Out:
# 23

# %%
plt.plot(U_sol[-1, 1, :])
plt.ylim(-0.18, 0.18)
plt.xlabel("Iteration")
plt.ylabel("Steering rate (rad/s)")
# Out:
# Text(0, 0.5, 'Steering rate (rad/s)')

# %%
plt.rcParams['text.usetex'] = False
plt.plot(X_sol_intermediate[-1, 4, :])
plt.xlabel('Iteration')
plt.ylabel("Velocity (m/s)")
plt.ylim(8, 12)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_927691/2548865046.py in <module>
#       1 plt.rcParams['text.usetex'] = False
# ----> 2 plt.plot(X_sol_intermediate[-1, 4, :])
#       3 plt.xlabel('Iteration')
#       4 plt.ylabel("Velocity (m/s)")
#       5 plt.ylim(8, 12)
#
# NameError: name 'X_sol_intermediate' is not defined

# %%
data = np.load('solution_gen_ref_circles_fsg.npz')
X_sol_intermediate = data['X_sol_intermediate']
U_sol = data['U_sol_intermediate']

plt.plot(U_sol[-1, 1, :])
plt.ylim(-0.5, 0.5)
plt.xlabel("Prediction Horizon (k)")
plt.ylabel("Steering rate (rad/s)")

# data = np.load('solution_halfspaces.npz')
# X_sol_intermediate_halfspaces = data['X_sol_intermediate']
# U_sol_halfspaces = data['U_sol_intermediate']

# plt.plot(U_sol_circles[-1, 1, :], '--', c='black')
# Out:
# Text(0, 0.5, 'Steering rate (rad/s)')

# %%
plt.rcParams['text.usetex'] = False
plt.plot(X_sol_intermediate[-1, 4, :])
plt.xlabel('Prediction Horizon (k)')
plt.ylabel("Velocity (m/s)")
plt.ylim(8, 12)
# Out:
# (8.0, 12.0)

# %%
last_sol = X_sol_intermediate[-1]
last_sol = last_sol[:2, :].T
print(last_sol)

# Save last solution to yaml file with structure of ros path message
import yaml
from nav_msgs.msg import Path
from geometry_msgs.msg import PoseStamped, Point

all_poses = []

# Iterate over path poses and create YAML entries
for pose in last_sol:
    print(pose)
    x_coord = float(pose[0])
    print(x_coord)
    y_coord = float(pose[1])
    pose_entry = {
        "header": {
            "frame_id": "ugr/map",
            "seq": 0,
            "stamp": {"nsecs": 0, "secs": 0},
        },
        "pose": {
            "position": {"x": x_coord, "y": y_coord, "z": 0},
            "orientation": {"x": 0, "y": 0, "z": 0, "w": 1},
        },
    }
    all_poses.append(pose_entry)

# Create the final YAML data structure
data = {
    "header": {
        "frame_id": "ugr/map",
        "seq": 0,
        "stamp": {"nsecs": 0, "secs": 0},
    },
    "poses": all_poses,
}

with open('raceline_fsg.yaml', 'w') as file:
    yaml.dump(data, file)
# Out:
# [[ 3.25080404 -1.17143224]
#  [ 3.74419538 -1.15219994]
#  [ 4.23751437 -1.13121626]
#  ...
#  [ 2.25992122 -1.11507504]
#  [ 2.75563631 -1.13839894]
#  [ 3.25080404 -1.17143224]]
# [ 3.25080404 -1.17143224]
# 3.250804036606569
# [ 3.74419538 -1.15219994]
# 3.7441953838521944
# [ 4.23751437 -1.13121626]
# 4.237514371809111
# [ 4.73075465 -1.10848186]
# 4.730754648430008
# [ 5.22390989 -1.08399795]
# 5.223909892967655
# [ 5.71697384 -1.0577666 ]
# 5.71697383875282
# [ 6.2099403  -1.02979101]
# 6.209940301427505
# [ 6.70280321 -1.0000758 ]
# 6.70280321275342
# [ 7.19555666 -0.96862735]
# 7.195556660103846
# [ 7.68819493 -0.93545407]
# 7.688194931713634
# [ 8.18071257 -0.90056675]
# 8.180712567719729
# [ 8.67310442 -0.86397887]
# 8.673104416973331
# [ 9.1653657  -0.82570696]
# 9.165365699544063
# [ 9.65749207 -0.78577091]
# 9.657492074765589
# [10.14947971 -0.74419433]
# 10.149479714590514
# [10.64132538 -0.70100492]
# 10.641325381929247
# [11.13302651 -0.65623482]
# 11.133026513542415
# [11.62458131 -0.60992096]
# 11.624581306938595
# [12.11598881 -0.56210549]
# 12.115988810598097
# [12.60724902 -0.51283611]
# 12.607249016698692
# [13.09836296 -0.46216646]
# 13.09836295535989
# [13.58933279 -0.41015656]
# 13.589332789248314
# [14.08016191 -0.35687316]
# 14.0801619071973
# [14.57085502 -0.30239018]
# 14.570855015288586
# [15.06141822 -0.24678911]
# 15.061418223622582
# [15.55185913 -0.19015942]
# 15.551859126765853
# [16.04218688 -0.132599  ]
# 16.042186875609747
# [16.53241224 -0.07421459]
# 16.53241223810245
# [ 1.70225476e+01 -1.51222069e-02]
# 17.022547646028002
# [17.51260722  0.04455241]
# 17.512607224699995
# [18.0026068   0.10467334]
# 18.002606802114677
# [18.49256389  0.16509404]
# 18.492563893768697
# [18.98249766  0.22565688]
# 18.9824976589906
# [19.47242882  0.28619266]
# 19.47242882426357
# [19.96237957  0.34652017]
# 19.96237956863056
# [20.45237337  0.40644569]
# 20.452373365872713
# [20.94243478  0.4657625 ]
# 20.942434777740452
# [21.43258919  0.52425043]
# 21.43258919209483
# [21.9228625   0.58167535]
# 21.922862499388284
# [22.4132807   0.63778867]
# 22.413280700482208
# [22.90386944  0.69232687]
# 22.903869438367614
# [23.39465345  0.74501101]
# 23.394653445931247
# [23.8856559   0.79554626]
# 23.885655901498378
# [24.37689768  0.84362141]
# 24.37689768349479
# [24.86839652  0.88890842]
# 24.868396515213572
# [25.36016599  0.93106198]
# 25.360165990360294
# [25.85221447  0.96971913]
# 25.852214469797577
# [26.34454384  1.00449883]
# 26.344543839735348
# [-1.70262272 -1.27860076]
# -1.7026227186208707
# [-1.20939832 -1.22412199]
# -1.2093983231688838
# [-0.71519211 -1.17936187]
# -0.7151921072360262
# [-0.22019647 -1.14432559]
# -0.22019646688482777
# [ 0.27539675 -1.11901693]
# 0.2753967464298882
# [ 0.77139611 -1.1034381 ]
# 0.7713961076556154
# [ 1.26761052 -1.09758957]
# 1.2676105155248694
# [ 1.76384911 -1.1014698 ]
# 1.76384911015497
# [ 2.25992122 -1.11507504]
# 2.2599212154470063
# [ 2.75563631 -1.13839894]
# 2.7556363108044244
# [ 3.25080404 -1.17143224]
# 3.250804036606569

# %%
# read npz file
data = np.load('solution_tracking_halfspaces.npz')
X_sol_intermediate = data['X_sol_intermediate']
U_sol = data['U_sol_intermediate']
inf_pr = data['info_pr']
inf_du = data['info_du']
# obj = data['info_obj']
exec_times = data['exec_times']

exec_times_halfspaces = exec_times

fig, ax = plt.subplots()

ax.plot(np.arange(len(inf_pr)), inf_pr, label="inf_pr")
ax.plot(np.arange(len(inf_du)), inf_du, label="inf_du")

ax.legend(loc="upper right")
ax.set_yscale("log")
plt.show()

num_plots = len(X_sol_intermediate)
print(num_plots)

colors = cm.viridis(np.linspace(0, 1, num_plots))
# temp_colors = cm.viridis(np.linspace(0, 1, 10))
# for i, x in enumerate(X_sol_intermediate[:]):
#     plt.plot(x[0], x[1], color=colors[i], label=f'Plot {i+1}')
    
# # plt.legend()
# plt.show()

# plt.show()
# Out:
# 11075

# %%
# read npz file
data = np.load('solution_tracking_circles.npz')
X_sol_intermediate = data['X_sol_intermediate']
U_sol = data['U_sol_intermediate']
inf_pr = data['info_pr']
inf_du = data['info_du']
# obj = data['info_obj']
exec_times = data['exec_times']

fig, ax = plt.subplots()

ax.plot(np.arange(len(inf_pr)), inf_pr, label="inf_pr")
ax.plot(np.arange(len(inf_du)), inf_du, label="inf_du")

ax.legend(loc="upper right")
ax.set_yscale("log")
plt.show()

num_plots = len(X_sol_intermediate)
print(num_plots)

colors = cm.viridis(np.linspace(0, 1, num_plots))
# temp_colors = cm.viridis(np.linspace(0, 1, 10))
# for i, x in enumerate(X_sol_intermediate[:]):
#     plt.plot(x[0], x[1], color=colors[i], label=f'Plot {i+1}')
    
# # plt.legend()
# plt.show()

# plt.show()
# Out:
# 9525

# %%
plt.hist(exec_times_halfspaces, bins=1000, color='g', label='Halfspaces', density=True, alpha=0.7)
plt.hist(exec_times, bins=100, color='m', label='Circles', density=True, alpha=0.7)
plt.xlim(0, 0.20)
plt.xlabel("Execution time (s)", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.legend(fontsize=12)
print(np.mean(exec_times))
print(np.std(exec_times))
# Out:
# 0.0477229550295858
# 0.016499157732072268

# %%
# read npz file
data = np.load('solution_tracking_raceline_halfspaces.npz')
X_sol_intermediate = data['X_sol_intermediate']
U_sol = data['U_sol_intermediate']
inf_pr = data['info_pr']
inf_du = data['info_du']
# obj = data['info_obj']
exec_times = data['exec_times']
exec_times_halfspaces = exec_times

fig, ax = plt.subplots()

ax.plot(np.arange(len(inf_pr)), inf_pr, label="inf_pr")
ax.plot(np.arange(len(inf_du)), inf_du, label="inf_du")

ax.legend(loc="upper right")
ax.set_yscale("log")
plt.show()

num_plots = len(X_sol_intermediate)
print(num_plots)

colors = cm.viridis(np.linspace(0, 1, num_plots))
# temp_colors = cm.viridis(np.linspace(0, 1, 10))
# for i, x in enumerate(X_sol_intermediate[:]):
#     plt.plot(x[0], x[1], color=colors[i], label=f'Plot {i+1}')
    
# # plt.legend()
# plt.show()

# plt.show()
# Out:
# 9525

# %%
plt.hist(exec_times, bins=250, density=True)
plt.xlim(0, 0.20)
plt.xlabel("Execution time (s)", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
print(exec_times)
print(np.mean(exec_times))
print(np.std(exec_times))
# Out:
# [0.185687 0.046611 0.058962 0.034561 0.048218 0.044819 0.036529 0.036744
#  0.04282  0.034274 0.057128 0.099947 0.069042 0.048152 0.049544 0.048357
#  0.050353 0.051343 0.08401  0.064632 0.063276 0.065308 0.040496 0.05404
#  0.039033 0.042051 0.03872  0.050866 0.061956 0.050248 0.050966 0.051497
#  0.056061 0.047925 0.043219 0.078939 0.052256 0.045666 0.070101 0.058
#  0.088954 0.051677 0.059995 0.042628 0.061845 0.044915 0.060523 0.059278
#  0.048593 0.038672 0.035614 0.038518 0.043208 0.03497  0.039196 0.031887
#  0.0453   0.03806  0.03385  0.035585 0.046401 0.041509 0.039525 0.042133
#  0.053271 0.040141 0.036121 0.040576 0.04659  0.034225 0.041552 0.144196
#  0.05177  0.036611 0.05434  0.046767 0.034517 0.057235 0.082708 0.037838
#  0.03994  0.042291 0.050443 0.051131 0.037414 0.068252 0.084044 0.057471
#  0.061523 0.062547 0.060108 0.050956 0.059451 0.100041 0.113349 0.056389
#  0.039207 0.045438 0.054245 0.054191 0.048266 0.034343 0.032958 0.037626
#  0.038767 0.036401 0.043426 0.046175 0.066619 0.068558 0.060298 0.071558
#  0.066416 0.051388 0.056631 0.054667 0.05553  0.058924 0.050363 0.055586
#  0.050235 0.051491 0.04962  0.047139 0.061481 0.045768 0.045896 0.037323
#  0.036495 0.043897 0.069749 0.031954 0.034545 0.078887 0.032403 0.033798
#  0.032435 0.064915 0.040115 0.034251 0.038157 0.036026 0.040113 0.040233
#  0.033575 0.03238  0.039323 0.051983 0.033912 0.037978 0.033699 0.040515
#  0.053955 0.046395 0.088707 0.058563 0.085683 0.070813 0.062481 0.067492
#  0.066607 0.055541 0.054541 0.057775 0.054533 0.040342 0.042669 0.058964
#  0.046221 0.043922 0.04163  0.045895 0.044298 0.050107 0.037872 0.040654
#  0.045697 0.051697 0.040301 0.042035 0.051855 0.054554 0.050697 0.047847
#  0.041132 0.038964 0.062507 0.052348 0.051775 0.054466 0.042215 0.054344
#  0.05297  0.063146 0.047952 0.057152 0.054261 0.046684 0.061255 0.032562
#  0.05203  0.048426 0.077748 0.033246 0.038368 0.037105 0.033965 0.047867
#  0.059901 0.097094 0.058483 0.051926 0.055058 0.054805 0.05941  0.174904
#  0.079465 0.067953 0.068422 0.06089  0.077338 0.040699 0.073157 0.05338
#  0.039469 0.038836 0.047793 0.04123  0.049217 0.063691 0.037739 0.037312
#  0.039732 0.032703 0.048572 0.053263 0.054111 0.052714 0.054776 0.054283
#  0.045136 0.065286 0.042804 0.039312 0.039238 0.043519 0.04739  0.039149
#  0.046798 0.040274 0.044338 0.04033  0.043124 0.034128 0.040607 0.03848
#  0.034485 0.0437   0.043466 0.050999 0.056393]
# 0.0477229550295858
# 0.016499157732072268

# %%
# read npz file
data = np.load('solution_tracking_raceline_circles.npz')
X_sol_intermediate = data['X_sol_intermediate']
U_sol = data['U_sol_intermediate']
inf_pr = data['info_pr']
inf_du = data['info_du']
# obj = data['info_obj']
exec_times = data['exec_times']

fig, ax = plt.subplots()

ax.plot(np.arange(len(inf_pr)), inf_pr, label="inf_pr")
ax.plot(np.arange(len(inf_du)), inf_du, label="inf_du")

ax.legend(loc="upper right")
ax.set_yscale("log")
plt.show()

num_plots = len(X_sol_intermediate)
print(num_plots)

colors = cm.viridis(np.linspace(0, 1, num_plots))
# temp_colors = cm.viridis(np.linspace(0, 1, 10))
# for i, x in enumerate(X_sol_intermediate[:]):
#     plt.plot(x[0], x[1], color=colors[i], label=f'Plot {i+1}')
    
# # plt.legend()
# plt.show()

# plt.show()
# Out:
# 11596

# %%
plt.hist(exec_times_halfspaces, bins=250, color='g', label='Halfspaces', density=True, alpha=0.7)
plt.hist(exec_times, bins=250, color='m', label='Circles', density=True, alpha=0.7)
plt.xlim(0, 0.20)
plt.xlabel("Execution time (s)", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.legend(fontsize=12)
print(exec_times)
print(np.mean(exec_times))
print(np.std(exec_times))
# Out:
# [0.50593921 0.08490602 0.062536   ... 0.044908   0.043156   0.057633  ]
# 0.04346640763570007
# 0.01827015581676371

# %%
# read npz file
data = np.load('solution_gen_ref_halfspaces_fsc.npz')
X_sol_intermediate = data['X_sol_intermediate']
U_sol = data['U_sol_intermediate']
inf_pr = data['info_pr']
inf_du = data['info_du']
# obj = data['info_obj']
# exec_times = data['exec_times']

fig, ax = plt.subplots()

ax.plot(np.arange(len(inf_pr)), inf_pr, label="inf_pr")
ax.plot(np.arange(len(inf_du)), inf_du, label="inf_du")

ax.legend(loc="upper right")
ax.set_yscale("log")
plt.show()

num_plots = len(X_sol_intermediate)
print(num_plots)

colors = cm.viridis(np.linspace(0, 1, num_plots))
# temp_colors = cm.viridis(np.linspace(0, 1, 10))
# for i, x in enumerate(X_sol_intermediate[:]):
#     plt.plot(x[0], x[1], color=colors[i], label=f'Plot {i+1}')
    
# # plt.legend()
# plt.show()

# plt.show()
# Out:
# 45

# %%
plt.plot(U_sol[-1, 1, :])
plt.ylim(-0.5, 0.5)
plt.xlabel("Prediction Horizon (k)")
plt.ylabel("Steering rate (rad/s)")

# data = np.load('solution_halfspaces.npz')
# X_sol_intermediate_halfspaces = data['X_sol_intermediate']
# U_sol_halfspaces = data['U_sol_intermediate']

# plt.plot(U_sol_circles[-1, 1, :], '--', c='black')
# Out:
# Text(0, 0.5, 'Steering rate (rad/s)')

# %%
plt.rcParams['text.usetex'] = False
plt.plot(X_sol_intermediate[-1, 4, :])
plt.xlabel('Prediction Horizon (k)')
plt.ylabel("Velocity (m/s)")
plt.ylim(8, 12)
# Out:
# (8.0, 12.0)

# %%
# read npz file
data = np.load('solution_gen_ref_halfspaces_fsc.npz')
X_sol_intermediate_ref_halfspaces = data['X_sol_intermediate']
U_sol_ref_halfspaces = data['U_sol_intermediate']
inf_pr = data['info_pr']
inf_du = data['info_du']

data = np.load('solution_gen_ref_circles_fsc.npz')
X_sol_intermediate_ref_circles = data['X_sol_intermediate']
U_sol_ref_circles = data['U_sol_intermediate']
inf_pr = data['info_pr']
inf_du = data['info_du']

data = np.load("/home/zander/Documents/ugent_racing/autonomous2023/ROS/src/control/MPC_gen/data_gen/solution_gen_circles_fsc.npz")
X_sol_intermediate_mpcc_circles = data['X_sol_intermediate']
U_sol_mpcc_circles = data['U_sol_intermediate']
inf_pr = data['info_pr']
inf_du = data['info_du']

data = np.load("/home/zander/Documents/ugent_racing/autonomous2023/ROS/src/control/MPC_gen/data_gen/solution_gen_circles_lowN_fsc.npz")
X_sol_intermediate_mpcc_circles_lowN = data['X_sol_intermediate']
U_sol_mpcc_circles_lowN = data['U_sol_intermediate']
inf_pr = data['info_pr']
inf_du = data['info_du']

# %%
plt.rcParams['text.usetex'] = False
# plt.plot(X_sol_intermediate_ha[-1, 4, :])
plt.plot(X_sol_intermediate_ref_halfspaces[-1, 4, :], c="red", label="Reference-tracking with halfspaces")
plt.plot(X_sol_intermediate_ref_circles[-1, 4, :], c="m", label="Reference-tracking with circles")
plt.plot(X_sol_intermediate_mpcc_circles[-1, 4, :], c="green", label="MPCC with circles")
plt.plot(X_sol_intermediate_mpcc_circles_lowN[-1, 4, :], c="orange", label="MPCC with circles with tuned N")
plt.xlabel('Prediction Horizon (k)')
plt.ylabel("Velocity (m/s)")
plt.ylim(6, 14)
plt.legend()

# %%
plt.plot(U_sol_ref_halfspaces[-1, 1, :], c="red", label="Reference-tracking with halfspaces")
plt.plot(U_sol_ref_circles[-1, 1, :], c="m", label="Reference-tracking with circles")
plt.plot(U_sol_mpcc_circles[-1, 1, :], c="green", label="MPCC with circles")
plt.plot(U_sol_mpcc_circles_lowN[-1, 1, :], c="orange", label="MPCC with circles with tuned N")

plt.ylim(-1.5, 1.5)
plt.xlabel("Prediction Horizon (k)")
plt.ylabel("Steering rate (rad/s)")
plt.legend()
